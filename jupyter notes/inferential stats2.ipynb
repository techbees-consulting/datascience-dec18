# %%
import numpy as np

# %%
>>> 
>>>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris=pd.read_csv('C:/Users/ak/Desktop/techbees/datasets/iris.csv')

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
sns.scatterplot(x='sepal_length',y='petal_length',data=iris)
plt.show()

# %%
sns.scatterplot(x='petal_length',y='petal_width',data=iris)
plt.show()

# %%
X = np.stack((iris['petal_length'], iris['petal_width']), axis=0)

# %%
print(np.cov(iris['petal_length'], iris['petal_width']))
# Out:
# [[3.11317942 1.29638747]
#  [1.29638747 0.58241432]]
