# %%
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset("tips")

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
sns.relplot(x='total_bill',y='tip',col='time',data=tips)

# %%
sns.pairplot(data=tips,hue='time')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
os.chdir('C:/Users/ak/Desktop/techbees/data sets')

# %%
import pandas as pd
data_2015=pd.read_csv('hi_2015.csv')
data_2016=pd.read_csv('hi_2016.csv')
data_2017=pd.read_csv('hi_2017.csv')

# %%
data_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
# country              158 non-null object
# region               158 non-null object
# happiness_rank       158 non-null int64
# happiness_score      158 non-null float64
# standard_error       158 non-null float64
# gdp_pc               158 non-null float64
# family               158 non-null float64
# life_expectancy      158 non-null float64
# freedom              158 non-null float64
# corruption           158 non-null float64
# generosity           158 non-null float64
# dystopia_residual    158 non-null float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %%
data_2015=data_2015.head(20)
plt.figure(figsize=(12,10))
sns.barplot(x='country', y='happiness_score',data=data_2015)
# Place the region names at a 90-degree angle.
# plt.xticks(rotation= 90)
plt.xlabel('c')
plt.ylabel('c Happiness Score')
plt.title('Happiness rate for cs')
plt.show()

# %%
import numpy as np
data=pd.DataFrame(np.random.randn(500, 2),columns=['x','y'])

# %%
sns.relplot(x='x',y='y',data=data,kind='line')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
# x    500 non-null float64
# y    500 non-null float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %%
fmri = sns.load_dataset("fmri")
fmri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1064 entries, 0 to 1063
# Data columns (total 5 columns):
# subject      1064 non-null object
# timepoint    1064 non-null int64
# event        1064 non-null object
# region       1064 non-null object
# signal       1064 non-null float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 41.6+ KB

# %%
help(sns.relplot)
# Out:
# Help on function relplot in module seaborn.relational:
#
# relplot(x=None, y=None, hue=None, size=None, style=None, data=None, row=None, col=None, col_wrap=None, row_order=None, col_order=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, markers=None, dashes=None, style_order=None, legend='brief', kind='scatter', height=5, aspect=1, facet_kws=None, **kwargs)
#     Figure-level interface for drawing relational plots onto a FacetGrid.
#
#     This function provides access to several different axes-level functions
#     that show the relationship between two variables with semantic mappings
#     of subsets. The ``kind`` parameter selects the underlying axes-level
#     function to use:
#
#     - :func:`scatterplot` (with ``kind="scatter"``; the default)
#     - :func:`lineplot` (with ``kind="line"``)
#
#     Extra keyword arguments are passed to the underlying function, so you
# ...

# %%
sns.relplot(x="timepoint", y="signal", hue='region',kind="line", data=fmri)

# %%
sns.relplot(x="timepoint", y="signal", hue='region',kind="line",data=fmri.query("region == 'frontal'"))

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker",
            col="time", data=tips)

# %%
tips = sns.load_dataset("tips")
sns.catplot(x="day", y="total_bill", jitter=False,data=tips);

# %%
sns.catplot(x="day", y="total_bill", kind="swarm",data=tips);

# %%
sns.catplot(x="size", y="total_bill", kind="swarm",
            data=tips.query("size != 3"))

# %%
sns.catplot(x="total_bill", y="day", hue="time", kind="swarm", data=tips);

# %%
np.median(tips["total_bill"])
# Out:
# 17.795

# %%
from numpy import median
sns.barplot(x="day", y="tip", data=tips)
plt.show()

# %%
sns.catplot(x="day", y="total_bill", hue='sex',kind="violin", split=False,data=tips);

# %%
diamonds = sns.load_dataset("diamonds")
sns.catplot(x="color", y="price", kind="violin",
            data=diamonds.sort_values('color'))

# %%
sns.distplot(np.random.randn(100))

# %%
sns.pairplot(tips)

# %%
tips.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
cc=pd.read_csv("C:/Users/ak/Desktop/techbees/data sets/flickr_data.csv")

# %%
cc.shape
# Out:
# (8287, 15)

# %%
cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 15 columns):
# Identifier                0 non-null int64
# Edition Statement         0 non-null object
# Place of Publication      0 non-null object
# Date of Publication       0 non-null object
# Publisher                 0 non-null object
# Title                     0 non-null object
# Author                    0 non-null object
# Contributors              0 non-null object
# Corporate Author          0 non-null float64
# Corporate Contributors    0 non-null float64
# Former owner              0 non-null object
# Engraver                  0 non-null float64
# Issuance type             0 non-null object
# Flickr URL                0 non-null object
# Shelfmarks                0 non-null object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 0.0+ bytes

# %%
cc.isnull().sum()
# Out:
# Identifier                   0
# Edition Statement         7514
# Place of Publication         0
# Date of Publication        181
# Publisher                 4195
# Title                        0
# Author                    1778
# Contributors                 0
# Corporate Author          8287
# Corporate Contributors    8287
# Former owner              8286
# Engraver                  8287
# Issuance type                0
# Flickr URL                   0
# Shelfmarks                   0
# dtype: int64

# %%
cc.dropna(inplace=True)

# %%
cc.isnull().sum()
# Out:
# Identifier                0
# Edition Statement         0
# Place of Publication      0
# Date of Publication       0
# Publisher                 0
# Title                     0
# Author                    0
# Contributors              0
# Corporate Author          0
# Corporate Contributors    0
# Former owner              0
# Engraver                  0
# Issuance type             0
# Flickr URL                0
# Shelfmarks                0
# dtype: int64

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
sns.catplot(y="day", hue="time", kind="count", data=tips);
